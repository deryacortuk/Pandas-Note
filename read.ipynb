# %%
import pandas as pd

# %%
dataset=pd.read_csv("data.csv")

# %%
dataset
# Out:
#           EducationSector IndividualProject  Age  Gender City Influenced  \
# 0    Engineering Sciences                No   19    Male  Yes         No
# 1    Engineering Sciences               Yes   22    Male   No        Yes
# 2    Engineering Sciences                No   18    Male  Yes         No
# 3    Engineering Sciences               Yes   20    Male  Yes        Yes
# 4    Engineering Sciences               Yes   19    Male  Yes        Yes
# ..                    ...               ...  ...     ...  ...        ...
# 214  Engineering Sciences               Yes   19    Male  Yes        Yes
# 215  Engineering Sciences               Yes   19    Male  Yes         No
# 216  Engineering Sciences               Yes   22  Female  Yes        Yes
# 217  Engineering Sciences                No   19    Male  Yes         No
# 218  Engineering Sciences               Yes   18    Male   No        Yes
#
#      Perseverance  DesireToTakeInitiative  Competitiveness  SelfReliance  \
# ...

# %%
newdata=dataset.drop(["Age","City","Gender"],axis=1)

# %%
newdata
# Out:
#           EducationSector IndividualProject Influenced  Perseverance  \
# 0    Engineering Sciences                No         No             2
# 1    Engineering Sciences               Yes        Yes             3
# 2    Engineering Sciences                No         No             3
# 3    Engineering Sciences               Yes        Yes             3
# 4    Engineering Sciences               Yes        Yes             2
# ..                    ...               ...        ...           ...
# 214  Engineering Sciences               Yes        Yes             4
# 215  Engineering Sciences               Yes         No             2
# 216  Engineering Sciences               Yes        Yes             3
# 217  Engineering Sciences                No         No             1
# 218  Engineering Sciences               Yes        Yes             3
#
#      DesireToTakeInitiative  Competitiveness  SelfReliance  \
# 0                         2                3             3
# ...

# %%
newdata.to_csv("NewData.csv")

# %%
newdata.to_csv("NewData1.csv",index=False)

# %%
exceldata= pd.read_excel("data.xls")

# %%
exceldata
# Out:
#       Category      Product    Sales Quarter
# 0    Beverages         Chai   705.60   Qtr 1
# 1    Beverages         Chai   878.40   Qtr 2
# 2    Beverages         Chai  1174.50   Qtr 3
# 3    Beverages         Chai  2128.50   Qtr 4
# 4    Beverages        Chang  2720.80   Qtr 1
# ..         ...          ...      ...     ...
# 281    Seafood  Røgede sild  1953.67   Qtr 4
# 282    Seafood    Spegesild   803.52   Qtr 1
# 283    Seafood    Spegesild    91.80   Qtr 2
# 284    Seafood    Spegesild  1504.80   Qtr 3
# 285    Seafood    Spegesild   823.20   Qtr 4
#
# [286 rows x 4 columns]

# %%
exceldata["Cities"]="New York"

# %%
exceldata
# Out:
#       Category      Product    Sales Quarter    Cities
# 0    Beverages         Chai   705.60   Qtr 1  New York
# 1    Beverages         Chai   878.40   Qtr 2  New York
# 2    Beverages         Chai  1174.50   Qtr 3  New York
# 3    Beverages         Chai  2128.50   Qtr 4  New York
# 4    Beverages        Chang  2720.80   Qtr 1  New York
# ..         ...          ...      ...     ...       ...
# 281    Seafood  Røgede sild  1953.67   Qtr 4  New York
# 282    Seafood    Spegesild   803.52   Qtr 1  New York
# 283    Seafood    Spegesild    91.80   Qtr 2  New York
# 284    Seafood    Spegesild  1504.80   Qtr 3  New York
# 285    Seafood    Spegesild   823.20   Qtr 4  New York
#
# [286 rows x 5 columns]

# %%
exceldata.to_excel("newexcel.xls")

# %%
datanew = pd.read_html("https://www.contextures.com/xlsampledata01.html",header=0)

# %%
datanew
# Out:
# [     OrderDate   Region       Rep     Item  Units  UnitCost    Total
#  0     1/6/2020     East     Jones   Pencil     95      1.99   189.05
#  1    1/23/2020  Central    Kivell   Binder     50     19.99   999.50
#  2     2/9/2020  Central   Jardine   Pencil     36      4.99   179.64
#  3    2/26/2020  Central      Gill      Pen     27     19.99   539.73
#  4    3/15/2020     West   Sorvino   Pencil     56      2.99   167.44
#  5     4/1/2020     East     Jones   Binder     60      4.99   299.40
#  6    4/18/2020  Central   Andrews   Pencil     75      1.99   149.25
#  7     5/5/2020  Central   Jardine   Pencil     90      4.99   449.10
#  8    5/22/2020     West  Thompson   Pencil     32      1.99    63.68
#  9     6/8/2020     East     Jones   Binder     60      8.99   539.40
#  10   6/25/2020  Central    Morgan   Pencil     90      4.99   449.10
#  11   7/12/2020     East    Howard   Binder     29      1.99    57.71
# ...
